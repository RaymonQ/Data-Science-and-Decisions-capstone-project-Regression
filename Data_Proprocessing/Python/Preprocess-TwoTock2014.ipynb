# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#import missingno as msno 
df = pd.read_csv("data.csv", skiprows = 41)
df.head(5)
# Out:
#                                                  FID  file_id  \
# 0  anfog_dm_trajectory_data.fid-7f408395_174917ab...      185
# 1  anfog_dm_trajectory_data.fid-7f408395_174917ab...      185
# 2  anfog_dm_trajectory_data.fid-7f408395_174917ab...      185
# 3  anfog_dm_trajectory_data.fid-7f408395_174917ab...      185
# 4  anfog_dm_trajectory_data.fid-7f408395_174917ab...      185
#
#     deployment_name  platform_type platform_code   time_coverage_start  \
# 0  TwoRocks20130215  slocum glider         SL248  2013-02-15T03:13:29Z
# 1  TwoRocks20130215  slocum glider         SL248  2013-02-15T03:13:29Z
# 2  TwoRocks20130215  slocum glider         SL248  2013-02-15T03:13:29Z
# 3  TwoRocks20130215  slocum glider         SL248  2013-02-15T03:13:29Z
# 4  TwoRocks20130215  slocum glider         SL248  2013-02-15T03:13:29Z
#
#       time_coverage_end                  TIME  TIME_quality_control  LATITUDE  \
# 0  2013-03-11T20:14:20Z  2013-03-06T22:18:19Z                   1.0  -31.8027
# 1  2013-03-11T20:14:20Z  2013-03-06T22:18:22Z                   1.0  -31.8027
# 2  2013-03-11T20:14:20Z  2013-03-06T22:18:23Z                   1.0  -31.8027
# 3  2013-03-11T20:14:20Z  2013-03-06T22:18:26Z                   1.0  -31.8027
# 4  2013-03-11T20:14:20Z  2013-03-06T22:18:28Z                   1.0  -31.8027
#
#                         ...                        VCUR_GPS_quality_control  \
# 0                       ...                                             9.0
# 1                       ...                                             9.0
# 2                       ...                                             9.0
# 3                       ...                                             9.0
# 4                       ...                                             9.0
#
#    IRRAD443  IRRAD443_quality_control  IRRAD490  IRRAD490_quality_control  \
# 0    0.2722                       4.0    0.3541                       4.0
# 1    0.2642                       4.0    0.3463                       4.0
# 2    0.2579                       4.0    0.3398                       4.0
# 3    0.2579                       4.0    0.3375                       4.0
# 4    0.2579                       4.0    0.3375                       4.0
#
#    IRRAD555  IRRAD555_quality_control  IRRAD670  IRRAD670_quality_control  \
# 0    0.0712                       4.0    0.0114                       4.0
# 1    0.0675                       4.0    0.0133                       4.0
# 2    0.0675                       4.0    0.0128                       4.0
# 3    0.0666                       4.0    0.0104                       4.0
# 4    0.0634                       4.0    0.0104                       4.0
#
#                                              geom
# 0  POINT (114.98013440372972 -31.802694506260686)
# 1  POINT (114.98013265657173 -31.802693721740056)
# 2  POINT (114.98013155928385 -31.802693229028474)
# 3  POINT (114.98012962223838 -31.802692359243295)
# 4   POINT (114.9801285199303 -31.802691864277513)
#
# [5 rows x 58 columns]

# %%
df = df.drop(df[(df.PSAL < 2)].index)
df = df.drop(df[(df.PSAL > 41)].index)
#len(df)
df = df.drop(df[(df.CPHL < 0)].index)
df = df.drop(df[(df.CPHL > 100)].index)
#len(df)
df = df.drop(df[(df.CDOM < 0)].index)
df = df.drop(df[(df.CDOM > 400)].index)
#len(df)
df = df.drop(df[(df.VBSC < 0)].index)
df = df.drop(df[(df.VBSC > 0.1)].index)
#len(df)
df = df.drop(df[(df.IRRAD555 < 0) ].index)
df = df.drop(df[(df.IRRAD555 > 1000)].index)
len(df)
# Out:
# 3101188

# %%
name=df.deployment_name.unique()
print(name)
# Out:
# ['TwoRocks20130215' 'Leeuwin20131017' 'AIMS20151127'
#  'LizardIsland20131024' 'SpencerGulf20131031' 'TwoRocks20140808'
#  'StormBay20141017']

# %%
#show the location of missing value
sns.heatmap(df.isnull(), cbar=False)

# %%
#delete invalid columns VCUR,UCUR and NTRA
Two_14 = df[df['deployment_name'] == 'TwoRocks20140808']
del Two_14['NTRA']
del Two_14['UCUR']
del Two_14['VCUR']
#find the unique value in PSAL_quality_control
psalQ = Two_14.PSAL_quality_control.unique()
print(psalQ)
#keep good data only
psalValid=Two_14.loc[df['PSAL_quality_control'] == 1.]
Two_14.head(5)
# Out:
# [0. 1. 4. 3. 9.]
#                                                        FID  file_id  \
# 2266977  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2266978  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2266979  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2266980  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2266981  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
#
#           deployment_name  platform_type platform_code   time_coverage_start  \
# 2266977  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2266978  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2266979  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2266980  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2266981  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
#
#             time_coverage_end                  TIME  TIME_quality_control  \
# 2266977  2014-08-24T22:39:08Z  2014-08-08T02:48:07Z                   4.0
# 2266978  2014-08-24T22:39:08Z  2014-08-08T02:48:09Z                   4.0
# 2266979  2014-08-24T22:39:08Z  2014-08-08T02:48:11Z                   4.0
# 2266980  2014-08-24T22:39:08Z  2014-08-08T02:48:13Z                   4.0
# 2266981  2014-08-24T22:39:08Z  2014-08-08T02:48:15Z                   4.0
#
#          LATITUDE                       ...                        \
# 2266977  -31.8347                       ...
# 2266978  -31.8347                       ...
# 2266979  -31.8347                       ...
# 2266980  -31.8347                       ...
# 2266981  -31.8347                       ...
#
#          VCUR_GPS_quality_control  IRRAD443  IRRAD443_quality_control  \
# 2266977                       9.0   96.6469                       1.0
# 2266978                       9.0   90.7470                       1.0
# 2266979                       9.0   91.5329                       1.0
# 2266980                       9.0   87.4582                       1.0
# 2266981                       9.0   81.7736                       1.0
#
#          IRRAD490  IRRAD490_quality_control  IRRAD555  \
# 2266977   71.6836                       1.0   77.5327
# 2266978   83.0764                       1.0   82.2672
# 2266979   70.8977                       1.0   92.2485
# 2266980   73.7684                       1.0   73.1599
# 2266981   82.7899                       1.0   66.1490
#
#          IRRAD555_quality_control  IRRAD670  IRRAD670_quality_control  \
# 2266977                       1.0   64.2709                       1.0
# 2266978                       1.0   91.5810                       1.0
# 2266979                       1.0   99.1137                       1.0
# 2266980                       1.0   95.9498                       1.0
# 2266981                       1.0   92.1106                       1.0
#
#                                                    geom
# 2266977                     POINT (115.57435 -31.83472)
# 2266978                     POINT (115.57435 -31.83472)
# 2266979   POINT (115.57435833333332 -31.83471833333333)
# 2266980   POINT (115.57435833333332 -31.83471833333333)
# 2266981  POINT (115.57434333333335 -31.834713333333337)
#
# [5 rows x 55 columns]

# %%
from numpy import where
from netCDF4 import Dataset, num2date
from matplotlib.pyplot import figure, xlabel, ylabel, title, show

# Extract variable values and convert the time values into an array of datetime objects
TIME = pd.to_datetime(Two_14['TIME']).dt.date.values
psalData = Two_14['PSAL'].values
depthData = Two_14['DEPTH'].values

# %%
# plot depth and salinity(psal) timeseries
figure1 = figure( figsize=(13, 10), dpi=80, facecolor='w', edgecolor='k')

ax1 = figure1.add_subplot(111)
ax1.plot(TIME,psalData, 'b-')
ax1.set_xlabel('TIME')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('sea_water_salinity(PSAL)' + ' in units', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(TIME,depthData, 'r.')
ax2.set_ylabel('DEPTH' + ' in units', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')

show()

# %%
#detective the not good of PSAL
#it turns out that there are only two items is missing value,so we decide to delete it
psalMissing=Two_14.loc[df['PSAL_quality_control'] == 9.]
#print("the num of missing psal for PSAL is",len(psalMissing)) ------ #the ans is two before
Two_14.drop(df[df['PSAL_quality_control'] == 9.].index, inplace=True)
print("the num of missing psal for PSAL after deleting is",len(psalMissing))
psalInvalid = Two_14.loc[df['PSAL_quality_control'] != 1.]
#the ratio is extremely small which means that we can ignore the invalid data 
#we only focous on those that whose psal_quality_control is 1
print("the ratio of good quality data v.s. bad quality(including missing) is",round(len(psalInvalid)/len(psalValid),3))
# Out:
# the num of missing psal for PSAL after deleting is 2
# the ratio of good quality data v.s. bad quality(including missing) is 0.007

# %%
#update the Two_14 with psal good quality data only
Two_14 = psalValid

#####then I will do the features selection one by one

#PROFILE:glider_trajectory_profile_number
proQ = Two_14.PROFILE_quality_control.unique()
print(proQ) #all no_qc_performed


#DOX2:standard_name: moles_of_oxygen_per_unit_mass_in_sea_water
do2 = Two_14.DOX2_quality_control.unique()
print('the quality type of DOX2 are',do2)
do2bad=Two_14.loc[df['DOX2_quality_control'] == 4.]
print('the number of bad data for DOX2',len(do2bad),', and the pecentage is',round(len(do2bad)/len(Two_14),4)*100,'%')
#update Two_14
Two_14 = Two_14[(Two_14['DOX2_quality_control'] != 4.)]
do2missing = Two_14.loc[df['DOX2_quality_control'] != 1.]
print('number of missing value is:',len(do2missing),'and the pecentage is',round(len(do2missing)/len(Two_14),4)*100,'%')
do2missing.head(5)
# Out:
# [0.]
# the quality type of DOX2 are [9. 1. 4.]
# the number of bad data for DOX2 8 , and the pecentage is 0.0 %
# number of missing value is: 55056 and the pecentage is 8.08 %
#                                                        FID  file_id  \
# 2268964  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2268965  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2268966  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2268967  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2268968  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
#
#           deployment_name  platform_type platform_code   time_coverage_start  \
# 2268964  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2268965  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2268966  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2268967  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2268968  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
#
#             time_coverage_end                  TIME  TIME_quality_control  \
# 2268964  2014-08-24T22:39:08Z  2014-08-08T03:54:21Z                   1.0
# 2268965  2014-08-24T22:39:08Z  2014-08-08T03:54:23Z                   1.0
# 2268966  2014-08-24T22:39:08Z  2014-08-08T03:54:25Z                   1.0
# 2268967  2014-08-24T22:39:08Z  2014-08-08T03:54:27Z                   1.0
# 2268968  2014-08-24T22:39:08Z  2014-08-08T03:54:29Z                   1.0
#
#          LATITUDE                       ...                        \
# 2268964  -31.8255                       ...
# 2268965  -31.8255                       ...
# 2268966  -31.8255                       ...
# 2268967  -31.8255                       ...
# 2268968  -31.8255                       ...
#
#          VCUR_GPS_quality_control  IRRAD443  IRRAD443_quality_control  \
# 2268964                       9.0  104.5551                       1.0
# 2268965                       9.0  122.7953                       1.0
# 2268966                       9.0  100.1251                       1.0
# 2268967                       9.0   97.6680                       1.0
# 2268968                       9.0   87.6008                       1.0
#
#          IRRAD490  IRRAD490_quality_control  IRRAD555  \
# 2268964  126.8223                       1.0  115.8032
# 2268965  129.5895                       1.0  116.0941
# 2268966   90.9077                       1.0  102.0622
# 2268967   83.2426                       1.0   89.8697
# 2268968   89.7794                       1.0   84.0332
#
#          IRRAD555_quality_control  IRRAD670  IRRAD670_quality_control  \
# 2268964                       1.0  107.7138                       1.0
# 2268965                       1.0  120.9585                       1.0
# 2268966                       1.0   93.4221                       1.0
# 2268967                       1.0   98.2030                       1.0
# 2268968                       1.0   97.6172                       1.0
#
#                                                    geom
# 2268964  POINT (115.57007578502126 -31.825452931927956)
# 2268965  POINT (115.57007696589437 -31.825452656516653)
# 2268966   POINT (115.5700781775344 -31.825452373929682)
# 2268967  POINT (115.57007934959007 -31.825452100574847)
# 2268968   POINT (115.5700804701184 -31.825451839237562)
#
# [5 rows x 55 columns]

# %%
# Extract variable values and convert the time values into an array of datetime objects
TIME = pd.to_datetime(do2missing['TIME']).dt.date.values
do2Data = do2missing['DOX2'].values
depthData = do2missing['DEPTH'].values

# plot depth and DOX2 missing value timeseries
figure1 = figure( figsize=(10,6 ), dpi=80, facecolor='w', edgecolor='k')

ax1 = figure1.add_subplot(111)
ax1.plot(TIME,do2Data, 'b-')
ax1.set_xlabel('TIME')
ax1.set_title('the depth change for the missing DOX2 values')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('moles_of_oxygen_per_unit_mass_in_sea_water (DOX2)' + ' in units', color='b')
for tl in ax1.get_yticklabels():
    tl.set_color('b')

ax2 = ax1.twinx()
ax2.plot(TIME,depthData, 'r.')
ax2.set_ylabel('DEPTH' + ' in units', color='r')
for tl in ax2.get_yticklabels():
    tl.set_color('r')
    

# good quality DOX2
do2Valid=Two_14.loc[df['DOX2_quality_control'] == 1.]
TIME = pd.to_datetime(do2Valid['TIME']).dt.date.values
do2vData = do2Valid['DOX2'].values
depthvData = do2Valid['DEPTH'].values

# plot depth and DOX2 good quality data timeseries
figure2 = figure( figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

ax3 = figure2.add_subplot(111)
ax3.plot(TIME,do2vData, 'b-')
ax3.set_xlabel('TIME')
ax3.set_title('the depth change for the good quality of DOX2 values')
# Make the y-axis label and tick labels match the line color.
ax3.set_ylabel('moles_of_oxygen_per_unit_mass_in_sea_water (DOX2)' + ' in units', color='b')
for t3 in ax3.get_yticklabels():
    t3.set_color('b')

ax4 = ax3.twinx()
ax4.plot(TIME,depthvData, 'r.')
ax4.set_ylabel('DEPTH' + ' in units', color='r')
for t4 in ax4.get_yticklabels():
    t4.set_color('r')

show()

# %%
# Extract variable values and convert the time values into an array of datetime objects
TIME = pd.to_datetime(do2missing['TIME']).dt.date.values
do2Data = do2missing['DOX2'].values
tempData = do2missing['TEMP'].values

# plot depth and DOX2 missing value timeseries
figure3 = figure( figsize=(10,6 ), dpi=80, facecolor='w', edgecolor='k')

ax5 = figure3.add_subplot(111)
ax5.plot(TIME,do2Data, 'b-')
ax5.set_xlabel('TIME')
ax5.set_title('the temp change for the missing DOX2 values')
# Make the y-axis label and tick labels match the line color.
ax1.set_ylabel('moles_of_oxygen_per_unit_mass_in_sea_water (DOX2)' + ' in units', color='b')
for tl in ax5.get_yticklabels():
    tl.set_color('b')

ax6 = ax5.twinx()
ax6.plot(TIME,tempData, 'r.')
ax2.set_ylabel('TEMP' + ' in units', color='r')
for tl in ax6.get_yticklabels():
    tl.set_color('r')
    

# good quality DOX2
do2Valid=Two_14.loc[df['DOX2_quality_control'] == 1.]
TIME = pd.to_datetime(do2Valid['TIME']).dt.date.values
do2vData = do2Valid['DOX2'].values
tempvData = do2Valid['TEMP'].values

# plot depth and DOX2 good quality data timeseries
figure4 = figure( figsize=(10, 6), dpi=80, facecolor='w', edgecolor='k')

ax6 = figure4.add_subplot(111)
ax6.plot(TIME,do2vData, 'b-')
ax6.set_xlabel('TIME')
ax6.set_title('the temperature change for the good quality of DOX2 values')
# Make the y-axis label and tick labels match the line color.
ax6.set_ylabel('moles_of_oxygen_per_unit_mass_in_sea_water (DOX2)' + ' in units', color='b')
for t3 in ax6.get_yticklabels():
    t3.set_color('b')

ax7 = ax6.twinx()
ax7.plot(TIME,tempvData, 'r.')
ax7.set_ylabel('temp' + ' in units', color='r')
for t4 in ax7.get_yticklabels():
    t4.set_color('r')

show()

# %%
# corr plot for each variable, select those with corr>0.5 as training features
corr = do2Valid.corr() 
corr[(corr.abs()>0.5) & (corr.abs() < 1.0)].style.background_gradient(cmap='coolwarm')
# Out:
# D:\2018 UNSW\python-download\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col0 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col1 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col3 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col6 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col7 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col8 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col9 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col10 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col11 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col12 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col13 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col14 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col15 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col16 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col17 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col18 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col19 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col20 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col21 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col22 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col23 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col24 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col25 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col26 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col27 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col28 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col29 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col30 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col31 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col32 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col33 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col34 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col35 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col36 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col37 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col38 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col39 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col40 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col41 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col42 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col43 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col44 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col45 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow0_col46 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col0 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col1 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col2 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col3 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col5 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col6 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col7 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col8 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col9 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col10 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col11 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col12 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col13 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col14 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col15 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col16 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col17 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col18 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col19 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col20 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col21 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col22 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col23 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col24 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col25 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col26 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col27 {
#             background-color:  #3b4cc0;
#         }    #T_c56b7950_0c4c_11eb_8272_18dbf258cddfrow1_col28 {
#             background-color:  #3b4cc0;
#         }    #T_c56b795

# %%
#imputation data

# Train-test split

X = do2Valid[['PRES','DEPTH','PROFILE','TEMP','PSAL','CNDC','IRRAD443','IRRAD490','IRRAD555','IRRAD670']]
# Target value
y = do2Valid['DOX2'].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Import knn 
from sklearn.neighbors import KNeighborsClassifier

# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors = 3)

# Fit the classifier to the data
model = knn.fit(X_train,y_train.astype('int'))
y_pred = knn.predict(X_test)

# Test the accuracy score of the model
from sklearn.metrics import accuracy_score
print('the accuracy of testing data on DOX2 is:',accuracy_score(y_test.astype('int'), y_pred))
# Out:
# the accuracy of testing data on DOX2 is: 0.891786367301965

# %%
missing_dox2= do2missing['DOX2']
#predict the DOX2 value for the whole Two_14 dataset
df_missing_dox2 = pd.DataFrame(Two_14[['PRES','DEPTH','PROFILE','TEMP','PSAL','CNDC','IRRAD443','IRRAD490','IRRAD555','IRRAD670']])
imputed_dox2 = model.predict(df_missing_dox2)
print('the array of knn prediction:',imputed_dox2)
# Out:
# the array of knn prediction: [193 193 193 ... 189 189 189]

# %%
indicies_of_missing = Two_14[Two_14['DOX2'].isnull()].index # list of the missing indices
Two_14.head(5)
for fill_index, dataframe_index in enumerate(indicies_of_missing):
    if pd.isnull(Two_14.loc[dataframe_index, 'DOX2']):
        Two_14.loc[dataframe_index,'DOX2'] = imputed_dox2[fill_index]
    else:
        continue

# %%
print("the number of missing DOX2 after imputation is", Two_14['DOX2'].isnull().sum())
# Out:
# the number of missing DOX2 after imputation is 0

# %%
#do similar for VBSC  -- 86+9 keep bad delete
#VBSC: quality control flag for volume_scattering_function
vbQ = Two_14.VBSC_quality_control.unique() #has good/bad type : type 1 & 4

vbbad=Two_14.loc[df['VBSC_quality_control'] == 4.]
#update Two_14
Two_14 = Two_14[(Two_14['VBSC_quality_control'] != 4.)]
vbmissing = Two_14.loc[df['VBSC_quality_control'] != 1.]
print('number of missing value is:',len(vbmissing),'and the pecentage is',round(len(vbmissing)/len(Two_14),4)*100,'%')
# Out:
# number of missing value is: 0 and the pecentage is 0.0 %

# %%
#irrade 45% bad
#quality control flag for downwelling_spectral_irradiance_in_sea_water_beam1

ir4Q = Two_14.IRRAD443_quality_control.unique()
print('type of IRRAD443 is',ir4Q) 

ir4bad=Two_14.loc[df['IRRAD443_quality_control'] == 4.]
print('the number of bad data for IRRAD443',len(ir4bad),', and the pecentage is',round(len(ir4bad)/len(Two_14),4)*100,'%')
#update Two_14
Two_14 = Two_14[(Two_14['IRRAD443_quality_control'] != 4.)]
ir4missing = Two_14.loc[df['IRRAD443_quality_control'] != 1.]
print('number of missing value is:',len(do2missing),'and the pecentage is',round(len(ir4missing)/len(Two_14),4)*100,'%')
# Out:
# type of IRRAD443 [4. 1.]
# the number of bad data for IRRAD443 296939 , and the pecentage is 45.36 %
# number of missing value is: 55056 and the pecentage is 0.0 %

# %%
ir9Q = Two_14.IRRAD490_quality_control.unique()
print('type of IRRAD490',ir9Q) 
ir5Q = Two_14.IRRAD555_quality_control.unique()
print('type of IRRAD555',ir5Q) 
ir6Q = Two_14.IRRAD670_quality_control.unique()
print('type of IRRAD670',ir6Q) 
ir6bad=Two_14.loc[df['IRRAD670_quality_control'] == 4.]
print('the number of bad data for IRRAD670',len(ir6bad),', and the pecentage is',round(len(ir6bad)/len(Two_14),4)*100,'%')
#update Two_14
Two_14 = Two_14[(Two_14['IRRAD670_quality_control'] != 4.)]
# Out:
# type of IRRAD490 [1.]
# type of IRRAD555 [1.]
# type of IRRAD670 [1. 4.]
# the number of bad data for IRRAD670 182 , and the pecentage is 0.05 %

# %%
del Two_14['NTRA_quality_control']
del Two_14['UCUR_quality_control']
del Two_14['VCUR_quality_control']
#UCUR can only be calculated when the glider is close to the surface and gets an updated GPS fix
#THus UCUR_GPSand VCUR_GPS null value can be deleted

del Two_14['UCUR_GPS']
del Two_14['UCUR_GPS_quality_control']
del Two_14['VCUR_GPS']
del Two_14['VCUR_GPS_quality_control']
print(Two_14.isnull().sum())
#only HEAD exists non-value
print(Two_14.isnull().sum())
# Out:
# FID                            0
# file_id                        0
# deployment_name                0
# platform_type                  0
# platform_code                  0
# time_coverage_start            0
# time_coverage_end              0
# TIME                           0
# TIME_quality_control           0
# LATITUDE                       0
# LATITUDE_quality_control       0
# LONGITUDE                      0
# LONGITUDE_quality_control      0
# PRES                           0
# PRES_quality_control           0
# DEPTH                          0
# DEPTH_quality_control          0
# PROFILE                        0
# PROFILE_quality_control        0
# PHASE                          0
# PHASE_quality_control          0
# TEMP                           0
# TEMP_quality_control           0
# PSAL                           0
# PSAL_quality_control           0
# DOX1                           0
# DOX1_quality_control           0
# DOX2                           0
# DOX2_quality_control           0
# CPHL                           0
# CPHL_quality_control           0
# CDOM                           0
# CDOM_quality_control           0
# CNDC                           0
# CNDC_quality_control           0
# VBSC                           0
# VBSC_quality_control           0
# HEAD                         343
# HEAD_quality_control           0
# VCUR_GPS_quality_control       0
# IRRAD443                       0
# IRRAD443_quality_control       0
# IRRAD490                       0
# IRRAD490_quality_control       0
# IRRAD555                       0
# IRRAD555_quality_control       0
# IRRAD670                       0
# IRRAD670_quality_control       0
# geom                           0
# dtype: int64

# %%
#HEAD:TIME LATITUDE LONGITUDE


heQ = Two_14.HEAD_quality_control.unique()
print('type of HEAD',heQ)
hemissing=Two_14.loc[df['HEAD_quality_control'] == 9.]
print('the number of missing data for HEAD',len(hemissing),', and the pecentage is',round(len(hemissing)/len(Two_14),4)*100,'%')
#update Two_14
Two_14 = Two_14[(Two_14['HEAD_quality_control'] != 9.)]
# Out:
# type of HEAD [0. 9.]
# the number of missing data for HEAD 343 , and the pecentage is 0.1 %

# %%
print(Two_14.isnull().sum())
#there is no missing values 

#----------'TwoRocks20140808'---------  output the rawdata as CSV
Two_14.to_csv (r'C:\Users\xinyu\Desktop\data\TwoRocks20140808.csv', index = False, header=True)
print (Two_14)
# Out:
# FID                          0
# file_id                      0
# deployment_name              0
# platform_type                0
# platform_code                0
# time_coverage_start          0
# time_coverage_end            0
# TIME                         0
# TIME_quality_control         0
# LATITUDE                     0
# LATITUDE_quality_control     0
# LONGITUDE                    0
# LONGITUDE_quality_control    0
# PRES                         0
# PRES_quality_control         0
# DEPTH                        0
# DEPTH_quality_control        0
# PROFILE                      0
# PROFILE_quality_control      0
# PHASE                        0
# PHASE_quality_control        0
# TEMP                         0
# TEMP_quality_control         0
# PSAL                         0
# PSAL_quality_control         0
# DOX1                         0
# DOX1_quality_control         0
# DOX2                         0
# DOX2_quality_control         0
# CPHL                         0
# CPHL_quality_control         0
# CDOM                         0
# CDOM_quality_control         0
# CNDC                         0
# CNDC_quality_control         0
# VBSC                         0
# VBSC_quality_control         0
# HEAD                         0
# HEAD_quality_control         0
# VCUR_GPS_quality_control     0
# IRRAD443                     0
# IRRAD443_quality_control     0
# IRRAD490                     0
# IRRAD490_quality_control     0
# IRRAD555                     0
# IRRAD555_quality_control     0
# IRRAD670                     0
# IRRAD670_quality_control     0
# geom                         0
# dtype: int64
#                                                        FID  file_id  \
# 2269897  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269898  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269899  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269900  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269901  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269902  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269903  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269904  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269905  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269906  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269907  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269908  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269909  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269910  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269911  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269912  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269913  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269914  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269915  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269916  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269917  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269918  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269919  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269920  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269921  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269922  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269923  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269924  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269925  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# 2269926  anfog_dm_trajectory_data.fid-7f408395_17491812...      189
# ...                                                    ...      ...
# 2961154  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961155  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961156  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961158  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961159  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961160  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961161  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961162  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961163  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961165  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961166  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961167  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961168  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961169  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961170  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961171  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961172  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961173  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961174  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961175  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961176  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961177  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961178  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961179  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961180  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961181  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961182  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961183  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961184  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
# 2961186  anfog_dm_trajectory_data.fid-7f408395_17491821...      189
#
#           deployment_name  platform_type platform_code   time_coverage_start  \
# 2269897  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269898  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269899  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269900  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269901  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269902  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269903  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269904  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269905  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269906  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269907  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269908  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269909  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269910  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269911  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269912  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269913  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269914  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269915  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269916  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269917  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269918  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269919  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269920  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269921  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269922  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269923  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269924  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269925  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2269926  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# ...                   ...            ...           ...                   ...
# 2961154  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961155  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961156  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961158  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961159  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961160  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961161  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961162  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961163  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961165  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961166  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961167  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961168  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961169  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961170  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961171  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961172  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961173  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961174  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961175  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961176  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961177  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961178  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961179  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961180  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961181  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961182  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961183  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961184  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
# 2961186  TwoRocks20140808  slocum glider         SL281  2014-08-08T02:48:06Z
#
#             time_coverage_end                  TIME  TIME_quality_control  \
# 2269897  2014-08-24T22:39:08Z  2014-08-08T04:41:41Z                   1.0
# 2269898  2014-08-24T22:39:08Z  2014-08-08T04:41:43Z                   1.0
# 2269899  2014-08-24T22:39:08Z  2014-08-08T04:41:45Z                   1.0
# 2269900  2014-08-24T22:39:08Z  2014-08-08T04:41:47Z                   1.0
# 2269901  2014-08-24T22:39:08Z  2014-08-08T04:41:49Z                   1.0
# 2269902  2014-08-24T22:39:08Z  2014-08-08T04:41:51Z                   1.0
# 2269903  2014-08-24T22:39:08Z  2014-08-08T04:41:53Z                   1.0
# 2269904  2014-08-24T22:39:08Z  2014-08-08T04:41:55Z                   1.0
# 2269905  2014-08-24T22:39:08Z  2014-08-08T04:41:57Z                   1.0
# 2269906  2014-08-24T22:39:08Z  2014-08-08T04:41:59Z                   1.0
# 2269907  2014-08-24T22:39:08Z  2014-08-08T04:42:01Z                   1.0
# 2269908  2014-08-24T22:39:08Z  2014-08-08T04:42:03Z                   1.0
# 2269909  2014-08-24T22:39:08Z  2014-08-08T04:42:05Z                   1.0
# 2269910  2014-08-24T22:39:08Z  2014-08-08T04:42:07Z                   1.0
# 2269911  2014-08-24T22:39:08Z  2014-08-08T04:42:09Z                   1.0
# 2269912  2014-08-24T22:39:08Z  2014-08-08T04:42:11Z                   1.0
# 2269913  2014-08-24T22:39:08Z  2014-08-08T04:42:13Z                   1.0
# 2269914  2014-08-24T22:39:08Z  2014-08-08T04:42:15Z                   1.0
# 2269915  2014-08-24T22:39:08Z  2014-08-08T04:42:17Z                   1.0
# 2269916  2014-08-24T22:39:08Z  2014-08-08T04:42:19Z                   1.0
# 2269917  2014-08-24T22:39:08Z  2014-08-08T04:42:21Z                   1.0
# 2269918  2014-08-24T22:39:08Z  2014-08-08T04:42:23Z                   1.0
# 2269919  2014-08-24T22:39:08Z  2014-08-08T04:42:25Z                   1.0
# 2269920  2014-08-24T22:39:08Z  2014-08-08T04:42:27Z                   1.0
# 2269921  2014-08-24T22:39:08Z  2014-08-08T04:42:29Z                   1.0
# 2269922  2014-08-24T22:39:08Z  2014-08-08T04:42:31Z                   1.0
# 2269923  2014-08-24T22:39:08Z  2014-08-08T04:42:33Z                   1.0
# 2269924  2014-08-24T22:39:08Z  2014-08-08T04:42:35Z                   1.0
# 2269925  2014-08-24T22:39:08Z  2014-08-08T04:42:37Z                   1.0
# 2269926  2014-08-24T22:39:08Z  2014-08-08T04:42:39Z                   1.0
# ...                       ...                   ...                   ...
# 2961154  2014-08-24T22:39:08Z  2014-08-24T20:47:18Z                   1.0
# 2961155  2014-08-24T22:39:08Z  2014-08-24T20:47:20Z                   1.0
# 2961156  2014-08-24T22:39:08Z  2014-08-24T20:47:22Z                   1.0
# 2961158  2014-08-24T22:39:08Z  2014-08-24T20:47:24Z                   1.0
# 2961159  2014-08-24T22:39:08Z  2014-08-24T20:47:26Z                   1.0
# 2961160  2014-08-24T22:39:08Z  2014-08-24T20:47:28Z                   1.0
# 2961161  2014-08-24T22:39:08Z  2014-08-24T20:47:30Z                   1.0
# 2961162  2014-08-24T22:39:08Z  2014-08-24T20:47:32Z                   1.0
# 2961163  2014-08-24T22:39:08Z  2014-08-24T20:47:34Z                   1.0
# 2961165  2014-08-24T22:39:08Z  2014-08-24T20:47:38Z                   1.0
# 2961166  2014-08-24T22:39:08Z  2014-08-24T20:47:40Z                   1.0
# 2961167  2014-08-24T22:39:08Z  2014-08-24T20:47:42Z                   1.0
# 2961168  2014-08-24T22:39:08Z  2014-08-24T20:47:44Z                   1.0
# 2961169  2014-08-24T22:39:08Z  2014-08-24T20:47:46Z                   1.0
# 2961170  2014-08-24T22:39:08Z  2014-08-24T20:47:48Z                   1.0
# 2961171  2014-08-24T22:39:08Z  2014-08-24T20:47:50Z                   1.0
# 2961172  2014-08-24T22:39:08Z  2014-08-24T20:47:52Z                   1.0
# 2961173  2014-08-24T22:39:08Z  2014-08-24T20:47:54Z                   1.0
# 2961174  2014-08-24T22:39:08Z  2014-08-24T20:47:56Z                   1.0
# 2961175  2014-08-24T22:39:08Z  2014-08-24T20:47:58Z                   1.0
# 2961176  2014-08-24T22:39:08Z  2014-08-24T20:48:00Z                   1.0
# 2961177  2014-08-24T22:39:08Z  2014-08-24T20:48:02Z                   1.0
# 2961178  2014-08-24T22:39:08Z  2014-08-24T20:48:04Z                   1.0
# 2961179  2014-08-24T22:39:08Z  2014-08-24T20:48:06Z                   1.0
# 2961180  2014-08-24T22:39:08Z  2014-08-24T20:48:08Z                   1.0
# 2961181  2014-08-24T22:39:08Z  2014-08-24T20:48:10Z                   1.0
# 2961182  2014-08-24T22:39:08Z  2014-08-24T20:48:12Z                   1.0
# 2961183  2014-08-24T22:39:08Z  2014-08-24T20:48:14Z                   1.0
# 2961184  2014-08-24T22:39:08Z  2014-08-24T20:48:16Z                   1.0
# 2961186  2014-08-24T22:39:08Z  2014-08-24T20:48:20Z                   1.0
#
#          LATITUDE                       ...                        \
# 2269897  -31.8253                       ...
# 2269898  -31.8253                       ...
# 2269899  -31.8253                       ...
# 2269900  -31.8253                       ...
# 2269901  -31.8253                       ...
# 2269902  -31.8253                       ...
# 2269903  -31.8253                       ...
# 2269904  -31.8253                       ...
# 2269905  -31.8253                       ...
# 2269906  -31.8253                       ...
# 2269907  -31.8253                       ...
# 2269908  -31.8253                       ...
# 2269909  -31.8253                       ...
# 2269910  -31.8253                       ...
# 2269911  -31.8253                       ...
# 2269912  -31.8253                       ...
# 2269913  -31.8253                       ...
# 2269914  -31.8253                       ...
# 2269915  -31.8253                       ...
# 2269916  -31.8252                       ...
# 2269917  -31.8252                       ...
# 2269918  -31.8252                       ...
# 2269919  -31.8252                       ...
# 2269920  -31.8252                       ...
# 2269921  -31.8252                       ...
# 2269922  -31.8252                       ...
# 2269923  -31.8252                       ...
# 2269924  -31.8252                       ...
# 2269925  -31.8252                       ...
# 2269926  -31.8252                       ...
# ...           ...                       ...
# 2961154  -32.0943                       ...
# 2961155  -32.0943                       ...
# 2961156  -32.0943                       ...
# 2961158  -32.0943                       ...
# 2961159  -32.0943                       ...
# 2961160  -32.0943                       ...
# 2961161  -32.0943                       ...
# 2961162  -32.0943                       ...
# 2961163  -32.0943                       ...
# 2961165  -32.0943                       ...
# 2961166  -32.0943                       ...
# 2961167  -32.0943                       ...
# 2961168  -32.0943                       ...
# 2961169  -32.0943                       ...
# 2961170  -32.0943                       ...
# 2961171  -32.0943                       ...
# 2961172  -32.0943                       ...
# 2961173  -32.0943                       ...
# 2961174  -32.0943                       ...
# 2961175  -32.0943                       ...
# 2961176  -32.0943                       ...
# 2961177  -32.0943                       ...
# 2961178  -32.0943                       ...
# 2961179  -32.0943                       ...
# 2961180  -32.0943                       ...
# 2961181  -32.0943                       ...
# 2961182  -32.0943                       ...
# 2961183  -32.0943                       ...
# 2961184  -32.0942                       ...
# 2961186  -32.0942                       ...
#
#          VCUR_GPS_quality_control  IRRAD443  IRRAD443_quality_control  \
# 2269897                       9.0    2.7427                       1.0
# 2269898                       9.0    2.6761                       1.0
# 2269899                       9.0    2.7924                       1.0
# 2269900                       9.0    2.9639                       1.0
# 2269901                       9.0    3.1142                       1.0
# 2269902                       9.0    3.1042                       1.0
# 2269903                       9.0    3.0674                       1.0
# 2269904                       9.0    3.1338                       1.0
# 2269905                       9.0    3.2349                       1.0
# 2269906                       9.0    3.3696                       1.0
# 2269907                       9.0    3.5119                       1.0
# 2269908                       9.0    3.6927                       1.0
# 2269909                       9.0    3.9180                       1.0
# 2269910                       9.0    4.3713                       1.0
# 2269911                       9.0    4.6866                       1.0
# 2269912                       9.0    4.8768                       1.0
# 2269913                       9.0    4.8337                       1.0
# 2269914                       9.0    4.9624                       1.0
# 2269915                       9.0    5.4345                       1.0
# 2269916                       9.0    6.0143                       1.0
# 2269917                       9.0    6.5439                       1.0
# 2269918                       9.0    6.6441                       1.0
# 2269919                       9.0    6.7808                       1.0
# 2269920                       9.0    7.1687                       1.0
# 2269921                       9.0    7.7654                       1.0
# 2269922                       9.0    8.3119                       1.0
# 2269923                       9.0    9.0488                       1.0
# 2269924                       9.0    9.5521                       1.0
# 2269925                       9.0   10.0498                       1.0
# 2269926                       9.0   10.4647                       1.0
# ...                           ...       ...                       ...
# 2961154                       9.0    0.0054                       1.0
# 2961155                       9.0    0.0054                       1.0
# 2961156                       9.0    0.0054                       1.0
# 2961158                       9.0    0.0051                       1.0
# 2961159                       9.0    0.0033                       1.0
# 2961160                       9.0    0.0045                       1.0
# 2961161                       9.0    0.0054                       1.0
# 2961162                       9.0    0.0054                       1.0
# 2961163                       9.0    0.0054                       1.0
# 2961165                       9.0    0.0054                       1.0
# 2961166                       9.0    0.0052                       1.0
# 2961167                       9.0    0.0027                       1.0
# 2961168                       9.0    0.0027                       1.0
# 2961169                       9.0    0.0027                       1.0
# 2961170                       9.0    0.0042                       1.0
# 2961171                       9.0    0.0054                       1.0
# 2961172                       9.0    0.0054                       1.0
# 2961173                       9.0    0.0054                       1.0
# 2961174                       9.0    0.0054                       1.0
# 2961175                       9.0    0.0054                       1.0
# 2961176                       9.0    0.0054                       1.0
# 2961177                       9.0    0.0054                       1.0
# 2961178                       9.0    0.0054                       1.0
# 2961179                       9.0    0.0054                       1.0
# 2961180                       9.0    0.0054                       1.0
# 2961181                       9.0    0.0054                       1.0
# 2961182                       9.0    0.0054                       1.0
# 2961183                       9.0    0.0054                       1.0
# 2961184                       9.0    0.0054                       1.0
# 2961186                       9.0    0.0054                       1.0
#
#          IRRAD490  IRRAD490_quality_control  IRRAD555  \
# 2269897    6.4581                       1.0    1.9176
# 2269898    6.3014                       1.0    1.8485
# 2269899    6.4698                       1.0    1.9239
# 2269900    6.7593                       1.0    2.0429
# 2269901    7.0411                       1.0    2.1471
# 2269902    7.0360                       1.0    2.1243
# 2269903    6.9051                       1.0    2.0790
# 2269904    6.9825                       1.0    2.1141
# 2269905    7.0996                       1.0    2.1730
# 2269906    7.2795                       1.0    2.2478
# 2269907    7.5333                       1.0    2.3316
# 2269908    7.8801                       1.0    2.4349
# 2269909    8.2606                       1.0    2.5685
# 2269910    9.0455                       1.0    2.8914
# 2269911    9.5302                       1.0    3.1084
# 2269912    9.8703                       1.0    3.2232
# 2269913    9.7395                       1.0    3.1431
# 2269914    9.9243                       1.0    3.1737
# 2269915   10.6326                       1.0    3.4849
# 2269916   11.5210                       1.0    3.8872
# 2269917   12.3714                       1.0    4.2500
# 2269918   12.5118                       1.0    4.2641
# 2269919   12.6991                       1.0    4.3054
# 2269920   13.2521                       1.0    4.5325
# 2269921   14.0735                       1.0    4.9073
# 2269922   14.8357                       1.0    5.2660
# 2269923   16.0109                       1.0    5.7282
# 2269924   16.7175                       1.0    6.0321
# 2269925   17.3925                       1.0    6.3313
# 2269926   17.9739                       1.0    6.5330
# ...           ...                       ...       ...
# 2961154    0.0083                       1.0    0.0090
# 2961155    0.0083                       1.0    0.0103
# 2961156    0.0083                       1.0    0.0089
# 2961158    0.0080                       1.0    0.0107
# 2961159    0.0062                       1.0    0.0089
# 2961160    0.0074                       1.0    0.0101
# 2961161    0.0083                       1.0    0.0092
# 2961162    0.0066                       1.0    0.0099
# 2961163    0.0072                       1.0    0.0093
# 2961165    0.0083                       1.0    0.0108
# 2961166    0.0081                       1.0    0.0085
# 2961167    0.0056                       1.0    0.0108
# 2961168    0.0057                       1.0    0.0084
# 2961169    0.0075                       1.0    0.0102
# 2961170    0.0083                       1.0    0.0110
# 2961171    0.0068                       1.0    0.0095
# 2961172    0.0056                       1.0    0.0082
# 2961173    0.0064                       1.0    0.0091
# 2961174    0.0083                       1.0    0.0109
# 2961175    0.0083                       1.0    0.0110
# 2961176    0.0083                       1.0    0.0110
# 2961177    0.0083                       1.0    0.0098
# 2961178    0.0083                       1.0    0.0082
# 2961179    0.0083                       1.0    0.0082
# 2961180    0.0058                       1.0    0.0107
# 2961181    0.0080                       1.0    0.0110
# 2961182    0.0083                       1.0    0.0086
# 2961183    0.0083                       1.0    0.0082
# 2961184    0.0068                       1.0    0.0082
# 2961186    0.0056                       1.0    0.0101
#
#          IRRAD555_quality_control  IRRAD670  IRRAD670_quality_control  \
# 2269897                       1.0    0.0167                       1.0
# 2269898                       1.0    0.0167                       1.0
# 2269899                       1.0    0.0151                       1.0
# 2269900                       1.0    0.0139                       1.0
# 2269901                       1.0    0.0140                       1.0
# 2269902                       1.0    0.0166                       1.0
# 2269903                       1.0    0.0087                       1.0
# 2269904                       1.0    0.0163                       1.0
# 2269905                       1.0    0.0167                       1.0
# 2269906                       1.0    0.0167                       1.0
# 2269907                       1.0    0.0167                       1.0
# 2269908                       1.0    0.0167                       1.0
# 2269909                       1.0    0.0167                       1.0
# 2269910                       1.0    0.0167                       1.0
# 2269911                       1.0    0.0190                       1.0
# 2269912                       1.0    0.0194                       1.0
# 2269913                       1.0    0.0194                       1.0
# 2269914                       1.0    0.0194                       1.0
# 2269915                       1.0    0.0194                       1.0
# 2269916                       1.0    0.0202                       1.0
# 2269917                       1.0    0.0222                       1.0
# 2269918                       1.0    0.0229                       1.0
# 2269919                       1.0    0.0244                       1.0
# 2269920                       1.0    0.0228                       1.0
# 2269921                       1.0    0.0250                       1.0
# 2269922                       1.0    0.0255                       1.0
# 2269923                       1.0    0.0278                       1.0
# 2269924                       1.0    0.0278                       1.0
# 2269925                       1.0    0.0278                       1.0
# 2269926                       1.0    0.0278                       1.0
# ...                           ...       ...                       ...
# 2961154                       1.0    0.0139                       1.0
# 2961155                       1.0    0.0139                       1.0
# 2961156                       1.0    0.0139                       1.0
# 2961158                       1.0    0.0139                       1.0
# 2961159                       1.0    0.0139                       1.0
# 2961160                       1.0    0.0139                       1.0
# 2961161                       1.0    0.0086                       1.0
# 2961162                       1.0    0.0090                       1.0
# 2961163                       1.0    0.0128                       1.0
# 2961165                       1.0    0.0127                       1.0
# 2961166                       1.0    0.0009                       1.0
# 2961167                       1.0    0.0109                       1.0
# 2961168                       1.0    0.0080                       1.0
# 2961169                       1.0    0.0025                       1.0
# 2961170                       1.0    0.0076                       1.0
# 2961171                       1.0    0.0124                       1.0
# 2961172                       1.0    0.0138                       1.0
# 2961173                       1.0    0.0149                       1.0
# 2961174                       1.0    0.0113                       1.0
# 2961175                       1.0    0.0129                       1.0
# 2961176                       1.0    0.0139                       1.0
# 2961177                       1.0    0.0139                       1.0
# 2961178                       1.0    0.0115                       1.0
# 2961179                       1.0    0.0061                       1.0
# 2961180                       1.0    0.0131                       1.0
# 2961181                       1.0    0.0065                       1.0
# 2961182                       1.0    0.0128                       1.0
# 2961183                       1.0    0.0139                       1.0
# 2961184                       1.0    0.0139                       1.0
# 2961186                       1.0    0.0072                       1.0
#
#                                                    geom
# 2269897  POINT (115.57222792808511 -31.825346348356284)
# 2269898  POINT (115.57222648463298 -31.825340906669474)
# 2269899   POINT (115.5722250660004 -31.825335558550176)
# 2269900   POINT (115.57222364903284 -31.82533021670789)
# 2269901  POINT (115.57222221859628 -31.825324824088604)
# 2269902  POINT (115.57222088103285 -31.825319781592913)
# 2269903   POINT (115.57221948086439 -31.82531450308165)
# 2269904   POINT (115.5722180660224 -31.825309169252566)
# 2269905  POINT (115.57221665273916 -31.825303841299835)
# 2269906  POINT (115.57221524676788 -31.825298540912527)
# 2269907  POINT (115.57221383978342 -31.825293236705587)
# 2269908  POINT (115.57221243906936 -31.825287956137604)
# 2269909   POINT (115.5722110269906 -31.825282632725685)
# 2269910  POINT (115.57220962024705 -31.825277329426914)
# 2269911  POINT (115.57220820713385 -31.825272002115234)
# 2269912  POINT (115.57220679709565 -31.825266686395995)
# 2269913   POINT (115.5722053817081 -31.825261350510193)
# 2269914   POINT (115.57220396396825 -31.82525600575644)
# 2269915     POINT (115.572202558082 -31.82525070568966)
# 2269916  POINT (115.57220116489246 -31.825245453488417)
# 2269917    POINT (115.57219975068814 -31.8252401220633)
# 2269918   POINT (115.57219834298807 -31.82523481515858)
# 2269919   POINT (115.57219694140254 -31.82522953130518)
# 2269920  POINT (115.57219552805554 -31.825224203112054)
# 2269921    POINT (115.572194114914 -31.825218875693537)
# 2269922  POINT (115.57219270980005 -31.825213578538214)
# 2269923  POINT (115.57219129537609 -31.825208246285065)
# 2269924   POINT (115.57218989371262 -31.82520296213785)
# 2269925  POINT (115.57218848476555 -31.825197650532058)
# 2269926   POINT (115.57218699284337 -31.82519202611748)
# ...                                                 ...
# 2961154  POINT (115.56569940392609 -32.094335814874114)
# 2961155   POINT (115.56570062933699 -32.09433276429136)
# 2961156  POINT (115.56570185421613 -32.094329715032345)
# 2961158   POINT (115.56570308598938 -32.09432664861093)
# 2961159   POINT (115.56570431122714 -32.09432359845916)
# 2961160   POINT (115.56570554831161 -32.09432051881576)
# 2961161  POINT (115.56570677842781 -32.094317456519484)
# 2961162   POINT (115.56570800419112 -32.09431440505937)
# 2961163   POINT (115.56570923884567 -32.09431133146514)
# 2961165   POINT (115.56571169587522 -32.09430521484578)
# 2961166  POINT (115.56571293958174 -32.094302118717245)
# 2961167  POINT (115.56571416849842 -32.094299059407064)
# 2961168   POINT (115.56571540450086 -32.09429598245732)
# 2961169   POINT (115.56571663581656 -32.09429291717493)
# 2961170    POINT (115.56571786982188 -32.0942898451969)
# 2961171  POINT (115.56571909804606 -32.094286787610656)
# 2961172   POINT (115.56572029552815 -32.09428380655488)
# 2961173   POINT (115.56572152621936 -32.09428074282711)
# 2961174    POINT (115.5657227555194 -32.09427768256261)
# 2961175   POINT (115.56572399009356 -32.09427460916849)
# 2961176   POINT (115.56572522119284 -32.09427154442483)
# 2961177  POINT (115.56572644596069 -32.094268495442876)
# 2961178   POINT (115.56572768063998 -32.09426542178708)
# 2961179   POINT (115.56572890205662 -32.09426238114775)
# 2961180   POINT (115.56573013507266 -32.09425931163248)
# 2961181  POINT (115.56573136600501 -32.094256247304415)
# 2961182   POINT (115.56573259015455 -32.09425319986169)
# 2961183    POINT (115.5657338222864 -32.09425013254752)
# 2961184   POINT (115.56573505220474 -32.09424707074379)
# 2961186   POINT (115.56573751636334 -32.09424093637712)
#
# [357203 rows x 49 columns]

# %%
df.isnull().sum()
# Out:
# FID                                0
# file_id                            0
# deployment_name                    0
# platform_type                      0
# platform_code                      1
# time_coverage_start                1
# time_coverage_end                  1
# TIME                               1
# TIME_quality_control               1
# LATITUDE                        2077
# LATITUDE_quality_control           1
# LONGITUDE                       2077
# LONGITUDE_quality_control          1
# PRES                            6895
# PRES_quality_control               1
# DEPTH                           7687
# DEPTH_quality_control              1
# PROFILE                         1556
# PROFILE_quality_control            1
# PHASE                           7049
# PHASE_quality_control              1
# TEMP                            1410
# TEMP_quality_control               1
# PSAL                            7252
# PSAL_quality_control               1
# DOX1                          641383
# DOX1_quality_control               1
# DOX2                          770651
# DOX2_quality_control               1
# CPHL                          877544
# CPHL_quality_control               1
# CDOM                          877545
# CDOM_quality_control               1
# CNDC                            1786
# CNDC_quality_control               1
# VBSC                          877544
# VBSC_quality_control               1
# NTRA                         2861977
# NTRA_quality_control         2861977
# UCUR                         3100081
# UCUR_quality_control               1
# VCUR                         3100081
# VCUR_quality_control               1
# HEAD                            3843
# HEAD_quality_control               1
# UCUR_GPS                     3099715
# UCUR_GPS_quality_control           1
# VCUR_GPS                     3099715
# VCUR_GPS_quality_control           1
# IRRAD443                     1514766
# IRRAD443_quality_control     1514765
# IRRAD490                     1514766
# IRRAD490_quality_control     1514765
# IRRAD555                     1514766
# IRRAD555_quality_control     1514765
# IRRAD670                     1514766
# IRRAD670_quality_control     1514765
# geom                            2077
# dtype: int64
